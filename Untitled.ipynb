# %%
import spacy
print("Load successfully")
# Out:
# Load successfully

# %%
import spacy
import nltk
import PyPDF2
import pdfplumber

print("All libraries loaded successfully!")
# Out:
# All libraries loaded successfully!
